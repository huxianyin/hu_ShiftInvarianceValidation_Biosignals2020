# %%
import os
import sys
import tensorflow
import numpy as np
from keras.models import load_model
from utils import BlurPooling1D
from keras.utils import CustomObjectScope
from keras.utils import to_categorical
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
model_path = "Result_CNN_aug_pool1/results_max/models/1-model.h5"
with CustomObjectScope({"BlurPooling1D":BlurPooling1D}):
    model = load_model(model_path)

# %%
for weights in model.get_weights():
    print(weights.shape)
# Out:
# (16, 1, 32)
# (32,)
# (32,)
# (32,)
# (32,)
# (32,)
# (32,)
# (32,)
# (32,)
# (32,)
# (1600, 1000)
# (1000,)
# (1000, 2)
# (2,)

# %%
filters = np.transpose(model.get_weights()[0],[2,1,0])

# %%
filters.shape
# Out:
# (32, 1, 16)

# %%
for filt in filters:
    plt.plot(range(16),filt[0])
    #converted = to_categorical(np.array((filt<=0),np.float32)[0],2)
    #ratio = np.sum(converted,axis=0)
    #print(ratio)
    plt.show()

# %%
plt.imshow(np.squeeze(filters,axis=1),cmap="Reds",vmin=0,vmax=0.8)
plt.colorbar()
